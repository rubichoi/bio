# %% [markdown]
# ### pyQSAR
# #### 빠르시간안에 주어진 많은 수의 feature들로부터 몇개의 feature만을 선택하여 더 정확하게 end point값을 예측

# %%
import pandas as pd
csv_file_name = "qsar_input_file.csv"
sample_data = pd.read_csv(csv_file_name, sep=',')

X_data = sample_data.iloc[:,1:-1] # feature
y_data = sample_data.iloc[:,-1:] # end_point

# %%
#X_data   # Total dataframe
X_data.head()
# Out:
#    nAcid   ALogP    ALogp2      AMR       apol  naAromAtom  nAromBond  nAtom  \
# 0      0  2.8332  8.027022  15.5429   6.481000           0          0      5
# 1      0  0.6494  0.421720  13.7114   7.993379           0          0      9
# 2      1  0.8583  0.736679  13.6539   7.461793           0          0      8
# 3      0  2.7863  7.763468  27.3736  11.731000           0          0      8
# 4      0  0.6467  0.418221  17.4897  10.977172           0          0     12
#
#    nHeavyAtom  nH  ...        AMW     WTPT-1    WTPT-2     WTPT-3    WTPT-4  \
# 0           5   0  ...  29.582709   8.500000  1.700000   9.000000  0.000000
# 1           6   3  ...  11.112622  10.465990  1.744332   9.237437  2.332107
# 2           7   1  ...  14.249108  12.293055  1.756151  11.587713  4.654701
# 3           8   0  ...  23.237721  14.062500  1.757812  13.875000  0.000000
# 4           8   4  ...  11.001652  14.271680  1.783960  11.777389  2.362609
#
#    WTPT-5  WPATH  WPOL  XLogP  Zagreb
# ...

# %%
X_data.shape
# Out:
# (56, 1444)

# %%
y_data.head()
# Out:
#    end_point
# 0      2.592
# 1      4.538
# 2      3.927
# 3      2.858
# 4      4.186

# %% [markdown]
#  ## Remove empty feature

# %%
X_data = X_data.dropna(axis=1)

# %% [markdown]
# ##### 데이터의 값이 0인것도 지우나?

# %%
# 열 헤더 목록 가져오기
s = list(X_data.columns.values)
len(s)
# Out:
# 1407

# %%
for i in range(len(s)):
    X_data = X_data[X_data.s[i] != 0]

X_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_121/1214458026.py in <module>
#       1 for i in range(len(s)):
# ----> 2     X_data = X_data[X_data.s[i] != 0]
#       3
#       4 X_data.head()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 's'

# %% [markdown]
# ### 특정 문자가 들어간 데이터프레임 열 이름 검색하기

# %%
X_data.filter(regex='ETA')
# Out:
#     ETA_Alpha  ETA_AlphaP  ETA_dAlpha_A  ETA_dAlpha_B  ETA_Epsilon_1  \
# 0     2.69046     0.53809       0.03809       0.00000        1.38191
# 1     2.19046     0.36508       0.00000       0.13492        1.02328
# 2     2.52379     0.36054       0.00000       0.13946        1.25953
# 3     4.00000     0.50000       0.00000       0.00000        1.37500
# 4     2.97617     0.37202       0.00000       0.12798        1.00199
# 5     2.57142     0.42857       0.00000       0.07143        1.37143
# 6     4.35713     0.43571       0.00000       0.06429        0.78952
# 7     4.75713     0.43247       0.00000       0.06753        0.77899
# 8     5.42379     0.41721       0.00000       0.08279        0.91625
# 9     5.07142     0.46104       0.00000       0.03896        0.86191
# 10    2.14284     0.35714       0.00000       0.14286        1.44286
# 11    3.21426     0.35714       0.00000       0.14286        1.44286
# 12    4.80950     0.60119       0.10119       0.00000        1.27381
# ...

# %% [markdown]
# scatter로 그려보기 ->상관계수가 높은 feature는 제거

# %% [markdown]
# ### Data scaling

# %%
from sklearn.preprocessing import MinMaxScaler
header = list(X_data.columns.values)
scaler = MinMaxScaler()
X_data_scaled = scaler.fit_transform(X_data)
X_data = pd.DataFrame(X_data_scaled, columns = header)

# %%
X_data.head()
# Out:
#    nAcid     ALogP    ALogp2       AMR      apol  naAromAtom  nAromBond  \
# 0    0.0  0.443862  0.202583  0.112285  0.038257         0.0        0.0
# 1    0.0  0.092842  0.010520  0.054573  0.117191         0.0        0.0
# 2    1.0  0.126421  0.018474  0.052761  0.089446         0.0        0.0
# 3    0.0  0.436324  0.195927  0.485077  0.312265         0.0        0.0
# 4    0.0  0.092408  0.010431  0.173629  0.272921         0.0        0.0
#
#       nAtom  nHeavyAtom        nH  ...       AMW    WTPT-1    WTPT-2  \
# 0  0.000000    0.000000  0.000000  ...  0.818155  0.000000  0.000000
# 1  0.181818    0.045455  0.500000  ...  0.094669  0.047890  0.192789
# 2  0.136364    0.090909  0.166667  ...  0.217527  0.092396  0.244187
# 3  0.136364    0.136364  0.000000  ...  0.569617  0.135498  0.251413
# 4  0.318182    0.136364  0.666667  ...  0.090322  0.140594  0.365123
#
#      WTPT-3    WTPT-4  WTPT-5     WPATH  WPOL     XLogP    Zagreb
# ...
